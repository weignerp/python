# %% [markdown]
# <a href="https://colab.research.google.com/github/weignerp/python/blob/master/fillings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
from pandas import pandas as pd

# %%
idx_path = 'sample_data/company.20240102.idx'
names = ['Company Name','Form Type','CIK','Date Filed','File Name']
df = pd.read_fwf(idx_path, colspecs=[(0,61),(62,74),(74,84),(86,94),(98,146)], names=names, skiprows=11)
df.head(10)
# Out:
#                     Company Name Form Type  ...  Date Filed                                    File Name
# 0          1 800 FLOWERS COM INC       8-K  ...    20240102  edgar/data/1084869/0001437749-24-000106.txt
# 1            127 Capital, LLC/TX    SC 13D  ...    20240102  edgar/data/1991003/0001839882-24-000053.txt
# 2  180 DEGREE CAPITAL CORP. /NY/         4  ...    20240102   edgar/data/893739/0001289134-24-000002.txt
# 3  180 DEGREE CAPITAL CORP. /NY/         4  ...    20240102   edgar/data/893739/0001296720-24-000002.txt
# 4              1847 Holdings LLC         4  ...    20240102  edgar/data/1599407/0001213900-24-000276.txt
# 5                1ST SOURCE CORP         4  ...    20240102    edgar/data/34782/0000034782-24-000004.txt
# 6                1ST SOURCE CORP         4  ...    20240102    edgar/data/34782/0000034782-24-000005.txt
# 7                1ST SOURCE CORP         4  ...    20240102    edgar/data/34782/0000034782-24-000006.txt
# ...

# %%
# @title CIK vs Date Filed

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='CIK', y='Date Filed', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
